# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time

term = "bisbenzylisoquinolines"
start_year = 1945
end_year = 2025
csv_file = "pubmed_bisBIAs_results.csv"
columns = ["Year", "PMID", "DOI", "Abstract"]

# 初始化CSV文件
pd.DataFrame(columns=columns).to_csv(csv_file, index=False)


def get_literature_id(term, year):
    """获取指定年份的文献ID列表"""
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": f"{term} AND {year}[pdat]",
        "retmax": 100000  # 一次获取最多10万条记录
    }

    try:
        time.sleep(0.34)  # 遵守NCBI速率限制
        response = requests.get(base_url, params=params, timeout=10)
        response.raise_for_status()
    except Exception as e:
        print(f"Error fetching IDs for {year}: {str(e)}")
        return [], 0

    soup = BeautifulSoup(response.text, "xml")
    count = int(soup.find("Count").text) if soup.find("Count") else 0
    id_list = [id_tag.text for id_tag in soup.find_all("Id")]

    return id_list, count


def parse_article(article_text):
    """稳健的文献解析函数"""
    record = {"PMID": None, "DOI": None, "Abstract": None}

    try:
        # 使用更可靠的字段定位方式
        lines = [line.strip() for line in article_text.split('\n')]

        # PMID提取
        pmid_line = next(line for line in lines if line.startswith("PMID- "))
        record["PMID"] = pmid_line.split("- ")[1]

        # DOI提取
        for line in lines:
            if line.startswith("AID - ") and "[doi]" in line:
                record["DOI"] = line.split("- ")[1].split("[doi]")[0].strip()
                break

        # 摘要提取
        abstract = []
        in_abstract = False
        for line in lines:
            if line.startswith("AB  - "):
                in_abstract = True
                abstract.append(line[6:].strip())
            elif in_abstract:
                if line and not line.startswith(("PMID-", "AID -", "FAU -")):
                    abstract.append(line)
                else:
                    break
        record["Abstract"] = " ".join(abstract) if abstract else None

    except Exception as e:
        print(f"解析文献时发生错误: {str(e)}")

    return record


def get_detailed_info(id_list, year):
    """获取文献详细信息"""
    extracted_info = []
    if not id_list:
        return extracted_info

    # 分批处理，每批200个ID
    for i in range(0, len(id_list), 200):
        batch_ids = id_list[i:i + 200]
        params = {
            "db": "pubmed",
            "id": ",".join(batch_ids),
            "rettype": "medline",
            "retmode": "text"
        }

        try:
            time.sleep(0.34)
            response = requests.get(
                "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi",
                params=params,
                timeout=10
            )
            response.raise_for_status()
        except Exception as e:
            print(f"Error fetching details for {year} batch {i}: {str(e)}")
            continue

        # 使用正则表达式分割文献记录（保留完整PMID行）
        records = re.findall(r'PMID- .*?(?=\nPMID- |\Z)', response.text, flags=re.DOTALL)

        for record_text in records:
            parsed = parse_article(record_text)
            if not parsed["PMID"]:
                print(f"跳过无法解析PMID的记录，年份：{year}")
                continue
            extracted_info.append([
                year,
                parsed["PMID"],
                parsed["DOI"],
                parsed["Abstract"]
            ])

    return extracted_info


# 主循环处理每个年份
for year in range(start_year, end_year + 1):
    print(f"Processing year {year}...")

    # 获取文献ID
    id_list, count = get_literature_id(term, year)
    print(f"Found {count} articles for {year}")

    if count == 0:
        continue

    # 获取详细信息
    details = get_detailed_info(id_list, year)

    # 保存到CSV
    if details:
        pd.DataFrame(details, columns=columns).to_csv(
            csv_file, mode="a", header=False, index=False
        )
        print(f"Saved {len(details)} records for {year}\n")
    else:
        print(f"No details found for {year}\n")

print("All years processed!")
# Out:
# Processing year 1945...
# Found 4 articles for 1945
# Saved 4 records for 1945
#
# Processing year 1946...
# Found 16 articles for 1946
# Saved 16 records for 1946
#
# Processing year 1947...
# Found 45 articles for 1947
# Saved 45 records for 1947
#
# Processing year 1948...
# Found 32 articles for 1948
# Saved 32 records for 1948
#
# Processing year 1949...
# Found 39 articles for 1949
# Saved 39 records for 1949
#
# Processing year 1950...
# Found 81 articles for 1950
# Saved 81 records for 1950
#
# Processing year 1951...
# Found 70 articles for 1951
# Saved 70 records for 1951
#
# Processing year 1952...
# Found 65 articles for 1952
# Saved 65 records for 1952
#
# Processing year 1953...
# Found 76 articles for 1953
# Saved 76 records for 1953
#
# Processing year 1954...
# Found 54 articles for 1954
# Saved 54 records for 1954
#
# Processing year 1955...
# Found 42 articles for 1955
# Saved 42 records for 1955
#
# Processing year 1956...
# Found 60 articles for 1956
# Saved 60 records for 1956
#
# Processing year 1957...
# Found 61 articles for 1957
# Saved 61 records for 1957
#
# Processing year 1958...
# Found 43 articles for 1958
# Saved 43 records for 1958
#
# Processing year 1959...
# Found 58 articles for 1959
# Saved 58 records for 1959
#
# Processing year 1960...
# Found 48 articles for 1960
# Saved 48 records for 1960
#
# Processing year 1961...
# Found 51 articles for 1961
# Saved 51 records for 1961
#
# Processing year 1962...
# Found 105 articles for 1962
# Saved 105 records for 1962
#
# Processing year 1963...
# Found 211 articles for 1963
# Saved 211 records for 1963
#
# Processing year 1964...
# Found 286 articles for 1964
# Saved 286 records for 1964
#
# Processing year 1965...
# Found 200 articles for 1965
# Saved 200 records for 1965
#
# Processing year 1966...
# Found 235 articles for 1966
# Saved 235 records for 1966
#
# Processing year 1967...
# Found 287 articles for 1967
# Saved 287 records for 1967
#
# Processing year 1968...
# Found 342 articles for 1968
# Saved 342 records for 1968
#
# Processing year 1969...
# Found 346 articles for 1969
# Saved 346 records for 1969
#
# Processing year 1970...
# Found 355 articles for 1970
# Saved 355 records for 1970
#
# Processing year 1971...
# Found 384 articles for 1971
# Saved 384 records for 1971
#
# Processing year 1972...
# Found 498 articles for 1972
# Saved 498 records for 1972
#
# Processing year 1973...
# Found 516 articles for 1973
# Saved 516 records for 1973
#
# Processing year 1974...
# Found 622 articles for 1974
# Saved 622 records for 1974
#
# Processing year 1975...
# Found 647 articles for 1975
# Saved 647 records for 1975
#
# Processing year 1976...
# Found 643 articles for 1976
# Saved 643 records for 1976
#
# Processing year 1977...
# Found 723 articles for 1977
# Saved 723 records for 1977
#
# Processing year 1978...
# Found 656 articles for 1978
# Saved 656 records for 1978
#
# Processing year 1979...
# Found 651 articles for 1979
# Saved 651 records for 1979
#
# Processing year 1980...
# Found 641 articles for 1980
# Saved 641 records for 1980
#
# Processing year 1981...
# Found 671 articles for 1981
# Saved 671 records for 1981
#
# Processing year 1982...
# Found 678 articles for 1982
# Saved 678 records for 1982
#
# Processing year 1983...
# Found 757 articles for 1983
# Saved 757 records for 1983
#
# Processing year 1984...
# Found 763 articles for 1984
# Saved 763 records for 1984
#
# Processing year 1985...
# Found 839 articles for 1985
# Saved 839 records for 1985
#
# Processing year 1986...
# Found 846 articles for 1986
# Saved 846 records for 1986
#
# Processing year 1987...
# Found 812 articles for 1987
# Saved 812 records for 1987
#
# Processing year 1988...
# Found 875 articles for 1988
# Saved 875 records for 1988
#
# Processing year 1989...
# Found 829 articles for 1989
# Saved 829 records for 1989
#
# Processing year 1990...
# Found 832 articles for 1990
# Saved 832 records for 1990
#
# Processing year 1991...
# Found 854 articles for 1991
# Saved 854 records for 1991
#
# Processing year 1992...
# Found 769 articles for 1992
# Saved 769 records for 1992
#
# Processing year 1993...
# Found 779 articles for 1993
# Saved 779 records for 1993
#
# Processing year 1994...
# Found 699 articles for 1994
# Saved 699 records for 1994
#
# Processing year 1995...
# Found 698 articles for 1995
# Saved 698 records for 1995
#
# Processing year 1996...
# Found 651 articles for 1996
# Saved 651 records for 1996
#
# Processing year 1997...
# Found 632 articles for 1997
# Saved 632 records for 1997
#
# Processing year 1998...
# Found 664 articles for 1998
# Saved 664 records for 1998
#
# Processing year 1999...
# Found 643 articles for 1999
# Saved 643 records for 1999
#
# Processing year 2000...
# Found 656 articles for 2000
# Saved 656 records for 2000
#
# Processing year 2001...
# Found 643 articles for 2001
# Saved 643 records for 2001
#
# Processing year 2002...
# Found 574 articles for 2002
# Saved 574 records for 2002
#
# Processing year 2003...
# Found 598 articles for 2003
# Saved 598 records for 2003
#
# Processing year 2004...
# Found 622 articles for 2004
# Saved 622 records for 2004
#
# Processing year 2005...
# Found 656 articles for 2005
# Saved 656 records for 2005
#
# Processing year 2006...
# Found 582 articles for 2006
# Saved 582 records for 2006
#
# Processing year 2007...
# Found 570 articles for 2007
# Saved 570 records for 2007
#
# Processing year 2008...
# Found 595 articles for 2008
# Saved 595 records for 2008
#
# Processing year 2009...
# Found 637 articles for 2009
# Saved 637 records for 2009
#
# Processing year 2010...
# Found 672 articles for 2010
# Saved 672 records for 2010
#
# Processing year 2011...
# Found 671 articles for 2011
# Saved 671 records for 2011
#
# Processing year 2012...
# Found 667 articles for 2012
# Saved 667 records for 2012
#
# Processing year 2013...
# Found 678 articles for 2013
# Saved 678 records for 2013
#
# Processing year 2014...
# Found 639 articles for 2014
# Saved 639 records for 2014
#
# Processing year 2015...
# Found 653 articles for 2015
# Saved 653 records for 2015
#
# Processing year 2016...
# Found 678 articles for 2016
# Saved 678 records for 2016
#
# Processing year 2017...
# Found 651 articles for 2017
# Saved 651 records for 2017
#
# Processing year 2018...
# Found 661 articles for 2018
# Saved 661 records for 2018
#
# Processing year 2019...
# Found 627 articles for 2019
# Saved 627 records for 2019
#
# Processing year 2020...
# Found 730 articles for 2020
# Saved 730 records for 2020
#
# Processing year 2021...
# Found 687 articles for 2021
# Saved 687 records for 2021
#
# Processing year 2022...
# Found 625 articles for 2022
# Saved 625 records for 2022
#
# Processing year 2023...
# Found 524 articles for 2023
# Saved 524 records for 2023
#
# Processing year 2024...
# Found 691 articles for 2024
# Saved 691 records for 2024
#
# Processing year 2025...
# Found 275 articles for 2025
# Saved 275 records for 2025
#
# All years processed!
